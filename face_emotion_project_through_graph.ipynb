dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 63252113 (60M) [application/zip]
# Saving to: ‘dataset.zip?dl=0’
#
# dataset.zip?dl=0    100%[===================>]  60.32M  89.2MB/s    in 0.7s
#
# 2022-01-19 15:13:03 (89.2 MB/s) - ‘dataset.zip?dl=0’ saved [63252113/63252113]

# %%
#Extracting the dataset zip file
from zipfile import ZipFile
file_name = "dataset.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
import numpy as np
import cv2
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D
from tensorflow.keras.optimizers import Adam
from keras.layers import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = 'train'
val_dir = 'test'
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
#Building the CNN Model
emotion_model = Sequential()
emotion_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
emotion_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))
emotion_model.add(Flatten())
emotion_model.add(Dense(1024, activation='relu'))
emotion_model.add(Dropout(0.5))
emotion_model.add(Dense(7, activation='softmax'))

# %%
#Training the model over 50 epochs
emotion_model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.0001, decay=1e-6),metrics=['accuracy'])
emotion_model_info = emotion_model.fit_generator(
        train_generator,
        steps_per_epoch=28709 // 64,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=7178 // 64)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/50
# 448/448 [==============================] - 24s 26ms/step - loss: 1.8063 - accuracy: 0.2585 - val_loss: 1.7346 - val_accuracy: 0.3274
# Epoch 2/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.6403 - accuracy: 0.3600 - val_loss: 1.5671 - val_accuracy: 0.4004
# Epoch 3/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.5354 - accuracy: 0.4104 - val_loss: 1.4736 - val_accuracy: 0.4381
# Epoch 4/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.4660 - accuracy: 0.4363 - val_loss: 1.4210 - val_accuracy: 0.4545
# Epoch 5/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.4094 - accuracy: 0.4607 - val_loss: 1.3538 - val_accuracy: 0.4826
# Epoch 6/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.3588 - accuracy: 0.4856 - val_loss: 1.3165 - val_accuracy: 0.4934
# Epoch 7/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.3152 - accuracy: 0.4996 - val_loss: 1.2711 - val_accuracy: 0.5184
# Epoch 8/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.2775 - accuracy: 0.5157 - val_loss: 1.2481 - val_accuracy: 0.5223
# Epoch 9/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.2377 - accuracy: 0.5290 - val_loss: 1.2321 - val_accuracy: 0.5294
# Epoch 10/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.2102 - accuracy: 0.5411 - val_loss: 1.2185 - val_accuracy: 0.5389
# Epoch 11/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.1849 - accuracy: 0.5522 - val_loss: 1.1915 - val_accuracy: 0.5463
# Epoch 12/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.1553 - accuracy: 0.5660 - val_loss: 1.1745 - val_accuracy: 0.5548
# Epoch 13/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.1347 - accuracy: 0.5752 - val_loss: 1.1573 - val_accuracy: 0.5604
# Epoch 14/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.1102 - accuracy: 0.5852 - val_loss: 1.1451 - val_accuracy: 0.5677
# Epoch 15/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.0849 - accuracy: 0.5937 - val_loss: 1.1359 - val_accuracy: 0.5727
# Epoch 16/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.0663 - accuracy: 0.6033 - val_loss: 1.1248 - val_accuracy: 0.5794
# Epoch 17/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.0449 - accuracy: 0.6099 - val_loss: 1.1264 - val_accuracy: 0.5778
# Epoch 18/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.0197 - accuracy: 0.6223 - val_loss: 1.1130 - val_accuracy: 0.5794
# Epoch 19/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.9994 - accuracy: 0.6275 - val_loss: 1.0975 - val_accuracy: 0.5915
# Epoch 20/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.9773 - accuracy: 0.6353 - val_loss: 1.0929 - val_accuracy: 0.5968
# Epoch 21/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.9542 - accuracy: 0.6478 - val_loss: 1.0924 - val_accuracy: 0.5932
# Epoch 22/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.9335 - accuracy: 0.6510 - val_loss: 1.0869 - val_accuracy: 0.5963
# Epoch 23/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.9079 - accuracy: 0.6655 - val_loss: 1.0865 - val_accuracy: 0.5985
# Epoch 24/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.8912 - accuracy: 0.6701 - val_loss: 1.0802 - val_accuracy: 0.6037
# Epoch 25/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.8654 - accuracy: 0.6795 - val_loss: 1.0785 - val_accuracy: 0.5995
# Epoch 26/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.8430 - accuracy: 0.6895 - val_loss: 1.0751 - val_accuracy: 0.6076
# Epoch 27/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.8155 - accuracy: 0.7003 - val_loss: 1.0745 - val_accuracy: 0.6073
# Epoch 28/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.8005 - accuracy: 0.7084 - val_loss: 1.0737 - val_accuracy: 0.6080
# Epoch 29/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.7827 - accuracy: 0.7155 - val_loss: 1.0736 - val_accuracy: 0.6091
# Epoch 30/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.7595 - accuracy: 0.7212 - val_loss: 1.0883 - val_accuracy: 0.6048
# Epoch 31/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.7377 - accuracy: 0.7309 - val_loss: 1.0891 - val_accuracy: 0.6074
# Epoch 32/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.7094 - accuracy: 0.7386 - val_loss: 1.0907 - val_accuracy: 0.6094
# Epoch 33/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.6957 - accuracy: 0.7468 - val_loss: 1.0940 - val_accuracy: 0.6154
# Epoch 34/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.6725 - accuracy: 0.7542 - val_loss: 1.0913 - val_accuracy: 0.6165
# Epoch 35/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.6519 - accuracy: 0.7643 - val_loss: 1.0927 - val_accuracy: 0.6228
# Epoch 36/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.6366 - accuracy: 0.7682 - val_loss: 1.1118 - val_accuracy: 0.6182
# Epoch 37/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.6130 - accuracy: 0.7755 - val_loss: 1.0966 - val_accuracy: 0.6197
# Epoch 38/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.5940 - accuracy: 0.7857 - val_loss: 1.1078 - val_accuracy: 0.6221
# Epoch 39/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.5807 - accuracy: 0.7913 - val_loss: 1.1221 - val_accuracy: 0.6204
# Epoch 40/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.5591 - accuracy: 0.7960 - val_loss: 1.1231 - val_accuracy: 0.6237
# Epoch 41/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.5421 - accuracy: 0.8063 - val_loss: 1.1196 - val_accuracy: 0.6226
# Epoch 42/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.5222 - accuracy: 0.8113 - val_loss: 1.1333 - val_accuracy: 0.6214
# Epoch 43/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.5130 - accuracy: 0.8157 - val_loss: 1.1449 - val_accuracy: 0.6219
# Epoch 44/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.4954 - accuracy: 0.8191 - val_loss: 1.1444 - val_accuracy: 0.6208
# Epoch 45/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.4802 - accuracy: 0.8293 - val_loss: 1.1428 - val_accuracy: 0.6210
# Epoch 46/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.4658 - accuracy: 0.8317 - val_loss: 1.1603 - val_accuracy: 0.6222
# Epoch 47/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.4484 - accuracy: 0.8411 - val_loss: 1.1530 - val_accuracy: 0.6239
# Epoch 48/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.4399 - accuracy: 0.8406 - val_loss: 1.1738 - val_accuracy: 0.6205
# Epoch 49/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.4247 - accuracy: 0.8483 - val_loss: 1.1674 - val_accuracy: 0.6268
# Epoch 50/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.4095 - accuracy: 0.8524 - val_loss: 1.1895 - val_accuracy: 0.6230

# %%
#Saving the model
emotion_model.save('model.h5')

# %%
from keras.models import load_model
emotion_model = load_model('model.h5')

# %%
#Function for plotting the graph
def emotion_analysis(emotions):
    objects = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()

# %%
#CODE for Capturing an image on Colab from here: https://colab.research.google.com/notebook#fileId=1OnUy6eFE7XhdfGfAHDCqQxpwueTOj_NO

from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
take_photo()
# Out:
# 'photo.jpg'

# %%
#Function for pre-processing the image to obtain the cropped image
import cv2            
def facecrop(image):  
    facedata = '/content/haarcascade_frontalface_alt.xml'
    cascade = cv2.CascadeClassifier(facedata)

    img = cv2.imread(image)

    try:
    
        minisize = (img.shape[1],img.shape[0])
        miniframe = cv2.resize(img, minisize)

        faces = cascade.detectMultiScale(miniframe)

        for f in faces:
            x, y, w, h = [ v for v in f ]
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

            sub_face = img[y:y+h, x:x+w]

            
            cv2.imwrite('capture.jpg', sub_face)
            print ("Writing: " + image)

    except Exception as e:
        print (e)

   


if __name__ == '__main__':
    facecrop('/content/trump.jpg')

#Testing a file.

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt

#Passing pre-processed image to model and generating the output
file = '/content/capture.jpg'
true_image = image.load_img(file)
img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = emotion_model.predict(x)
emotion_analysis(custom[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48]);


plt.imshow(true_image)
plt.show()
# Out:
# Writing: /content/trump.jpg

# %%
facecrop('/content/hank1.jpg')

file = '/content/capture.jpg'
true_image = image.load_img(file)
img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = emotion_model.predict(x)
emotion_analysis(custom[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48]);


plt.imshow(true_image)
plt.show()
# Out:
# Writing: /content/hank1.jpg

# %%
facecrop('/content/putin.jpg')

file = '/content/capture.jpg'
true_image = image.load_img(file)
img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = emotion_model.predict(x)
emotion_analysis(custom[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48]);


plt.imshow(true_image)
plt.show()
# Out:
# Writing: /content/putin.jpg

# %%
facecrop('/content/white.jpg')

file = '/content/capture.jpg'
true_image = image.load_img(file)
img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = emotion_model.predict(x)
emotion_analysis(custom[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48]);


plt.imshow(true_image)
plt.show()
# Out:
# Writing: /content/white.jpg
